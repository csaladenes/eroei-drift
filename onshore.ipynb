# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from jupyterthemes import jtplot
# oceans16 | grade3 | chesterish | onedork | monokai | solarizedl
jtplot.style('solarized-light')

# %%
df=pd.read_excel('data/wind_farms_with_ws_2k_5k_sgouris edited.xlsx',sheetname='BASE')
df=df.dropna()
df=df.set_index(['ISO_CODE','Year'])
df=df[((df['POWER_KW']>0)&(df['POWER_KW']<1000000)&(df['OFFSHORE']=='no'))]

# %%
cs={'BR','AR','GB','CA','US','IN'}
for c in cs:
    x=[]
    y=[]
    z=[]
    for i in df.loc[c].sort_index().index.unique():
        x.append(i)
        try:
            if len(df.loc[c].loc[i]['POWER_KW'])>1:
                z.append(np.average(df.loc[c].loc[i]['WS_est'],weights=df.loc[c].loc[i]['POWER_KW'].astype(float).values))
        except:
            z.append(np.average(df.loc[c].loc[i]['WS_est']))
    #plt.plot(x,y,label=c)
    plt.plot(x,z,label=c)
plt.ylabel('Capacity weighted mean windspeed [m/s]')
plt.title("Onshore turbines")
plt.legend(loc=0)

# %%
cs={'FR','DE','CN','IT','ES'}
for c in cs:
    x=[]
    y=[]
    z=[]
    for i in df.loc[c].sort_index().index.unique():
        x.append(i)
        try:
            if len(df.loc[c].loc[i]['POWER_KW'])>1:
                z.append(np.average(df.loc[c].loc[i]['WS_est'],weights=df.loc[c].loc[i]['POWER_KW'].astype(float).values))
        except:
            z.append(np.average(df.loc[c].loc[i]['WS_est']))
    #plt.plot(x,y,label=c)
    plt.plot(x,z,label=c)
plt.ylabel('Capacity weighted mean windspeed [m/s]')
plt.title("Onshore turbines")
plt.legend(loc=0)

# %%
df=pd.read_excel('data/wind_farms_with_ws_2k_5k_sgouris edited.xlsx',sheetname='BASE')
df=df.dropna()
df=df.set_index('Year')
df=df[((df['POWER_KW']>0)&(df['OFFSHORE']=='no'))]

# %%
x=[]
y=[]
z=[]
for i in df.sort_index().index.unique():
    x.append(i)
    try:
        if len(df.loc[i]['POWER_KW'])>1:
            z.append(np.average(df.loc[i]['WS_est'],weights=df.loc[i]['POWER_KW'].astype(float).values))
    except:
        z.append(np.average(df.loc[i]['WS_est']))
plt.plot(x,z,label='WD')
plt.ylabel('Capacity weighted mean windspeed [m/s]')
plt.title("Onshore turbines")
plt.legend(loc=0)
